# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv')

# %%
data
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at
# 0     2017-03-13 12:36:56
# ...

# %%
data.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %% [markdown]
# Difference between 3rd quartile and 4th quartile in Order_amount and total_items is very high.

# %%
plt.boxplot(data['order_amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f020e8b730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f020e8bcd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f020e8b460>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f020ea62b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f020ea6580>],
#  'means': []}

# %% [markdown]
# We can observe a lot of outliers in order_amount

# %%
plt.boxplot(data['total_items'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f02a199250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f02a1997f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f02a1990a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f02a199d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f02a1a80a0>],
#  'means': []}

# %% [markdown]
# We can also observe outliers in total items.

# %%
data['order_amount'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(data['order_id'], data['order_amount'])
plt.xlabel("Order id")
plt.ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')

# %%
data['order_amount'].value_counts()
# Out:
# 153       87
# 306       85
# 354       82
# 160       75
# 156       75
#           ..
# 730        1
# 450        1
# 470        1
# 154350     1
# 650        1
# Name: order_amount, Length: 258, dtype: int64

# %%
data['total_items'].value_counts()
# Out:
# 2       1832
# 1       1830
# 3        941
# 4        293
# 5         77
# 2000      17
# 6          9
# 8          1
# Name: total_items, dtype: int64

# %%
data['shop_id'].value_counts()
# Out:
# 53    68
# 71    66
# 19    64
# 13    63
# 89    61
#       ..
# 74    38
# 56    37
# 67    37
# 38    35
# 85    35
# Name: shop_id, Length: 100, dtype: int64

# %%
plt.scatter(data['shop_id'], data['order_amount'])
plt.xlabel("Shop id")
plt.ylabel("Order Amount")
# Out:
# Text(0, 0.5, 'Order Amount')

# %% [markdown]
# We can see some orders from particular shop id are exceptionally high.

# %%
plt.scatter(data['user_id'], data['order_amount'])
plt.xlabel("User id")
plt.ylabel("Order Amount")
# Out:
# Text(0, 0.5, 'Order Amount')

# %% [markdown]
# Some abnormally high amounting orders from user ids.

# %%
plt.scatter(data['total_items'], data['order_amount'])
plt.xlabel("Total Items Purchased")
plt.ylabel("Order Amount")
# Out:
# Text(0, 0.5, 'Order Amount')

# %%
sorted_data = data.sort_values('order_amount', ascending= False )

# %%
sorted_data.head(30)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 2153      2154       42      607        704000         2000    credit_card
# 3332      3333       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# 4646      4647       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 4882      4883       42      607        704000         2000    credit_card
# 4056      4057       42      607        704000         2000    credit_card
# ...

# %% [markdown]
# 17 transactions amounting 704000 are done from same user from same shop at same time i.e. shop_id 42, user_id 607 and at 4 am & all are from credit card. But average item cost for these transactions is 352, hence these are bulk purchase orders.
# There are some orders where total_items are very less but order_amount is vert high. These transactions are driving average order value high. Like order_id 692, shop_id 78 ordered 6 items costing 154350 (average item cost = 25725). These are the outliers.

# %%
sorted_data2 = data.sort_values('total_items', ascending= False )

# %%
sorted_data2.head(25)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 2297      2298       42      607        704000         2000    credit_card
# 4056      4057       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 3332      3333       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# 15          16       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# ...

# %%
data['average item value'] = data['order_amount']/data['total_items']

# %%
data
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at  average item value
# ...

# %% [markdown]
# Adding new column of average item value for every order to help us analyze data better.

# %%
data.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items  \
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000
#
#        average item value
# count         5000.000000
# mean           387.742800
# std           2441.963725
# min             90.000000
# 25%            133.000000
# 50%            153.000000
# 75%            169.000000
# max          25725.000000

# %%
plt.hist(data['average item value'])
# Out:
# (array([4954.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#           46.]),
#  array([   90. ,  2653.5,  5217. ,  7780.5, 10344. , 12907.5, 15471. ,
#         18034.5, 20598. , 23161.5, 25725. ]),
#  <BarContainer object of 10 artists>)

# %%
exceptional_orders = st[st['average item value']> 500]

# %%
exceptional_orders
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 4420      4421       78      969         77175            3          debit
# 2906      2907       78      817         77175            3          debit
# 4505      4506       78      866         25725            1          debit
# 493        494       78      983         51450            2           cash
# 2452      2453       78      709         51450            2           cash
# 1452      1453       78      812         25725            1    credit_card
# 3167      3168       78      927         51450            2           cash
# 3403      3404       78      928         77175            3          debit
# 4918      4919       78      823         25725            1           cash
# 2773      2774       78      890         25725            1           cash
# 2492      2493       78      834        102900            4          debit
# ...

# %%
exceptional_orders.value_counts('order_amount')
# Out:
# order_amount
# 25725     19
# 51450     16
# 77175      9
# 102900     1
# 154350     1
# dtype: int64

# %% [markdown]
# All orders from shop_id 78 have same average item value of 25725. Lets explore data from this shop_id.

# %%
data[data['shop_id'] == 78 ]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 691        692       78      878        154350            6          debit
# 1056      1057       78      800         25725            1          debit
# 1193      1194       78      944         25725            1          debit
# 1204      1205       78      970         25725            1    credit_card
# 1259      1260       78      775         77175            3    credit_card
# 1384      1385       78      867         25725            1           cash
# ...

# %%
data_cleaned = data[data['shop_id'] != 78]
data_cleaned = data_cleaned[data_cleaned['order_amount'] != 704000]
data_cleaned
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at
# 0     2017-03-13 12:36:56
# ...

# %% [markdown]
# Removing Bulk Orders and Orders from shop_id = 78.

# %%
data_cleaned.describe()
# Out:
#           order_id      shop_id      user_id  order_amount  total_items
# count  4937.000000  4937.000000  4937.000000   4937.000000  4937.000000
# mean   2499.551347    49.846465   849.752279    302.580514     1.994734
# std    1444.069407    29.061131    86.840313    160.804912     0.982821
# min       1.000000     1.000000   700.000000     90.000000     1.000000
# 25%    1248.000000    24.000000   775.000000    163.000000     1.000000
# 50%    2497.000000    50.000000   850.000000    284.000000     2.000000
# 75%    3751.000000    74.000000   925.000000    387.000000     3.000000
# max    5000.000000   100.000000   999.000000   1760.000000     8.000000

# %% [markdown]
# ## Answer 1-a
# ### Think about what could be going wrong with our calculation. Think about a better way to evaluate this data.
# Outliers were not removed while analyzing the dataset which caused high standard deviation
# There are some high value orders (from shop_id 42 and 78) which are causing this big deviation in Average Order Value for sneakers. We need more information why average item value is so high for orders from shop_id = 42. They might be selling expensive sneakers or it could be due to incorrect data, or due to data tampering etc. All have same average item value of 25725. There are total 46 such orders. 17 orders amounting 704000 are also contributing to higher AOV.

# %% [markdown]
# To better analyse this dataset, removing these outliers and bulk orders will help tremendously. We can also account average item value

# %% [markdown]
# ## Answer 1-b
# ### What metric would you report for this dataset?

# %% [markdown]
# Median is a more suitable metric to consider average order value in this case as it is not affected by outliers as much as mean. This can be observed in describe command on cleaned and original dataset as well.

# %% [markdown]
# ## Answer 1-c
# ### What is its value?

# %% [markdown]
# Average Order Value according to median is 284 which is more resonable.

# %% [markdown]
# ## Answer 2-a
# ### How many orders were shipped by Speedy Express in total?

# %% [markdown]
# `SELECT count(*) FROM Orders o, Shippers s where o.ShipperID=s.ShipperID and s.ShipperName='Speedy Express';`

# %% [markdown]
# Total 54 orders were shipped by Speedy Express.

# %% [markdown]
# ## Answer 2-b.
# ### What is the last name of the employee with the most orders?

# %% [markdown]
# `SELECT e.LastName FROM Orders o, Employees e where o.EmployeeID=e.EmployeeID group by o.EmployeeID order by count(o.EmployeeID) desc limit 1;`
#
# LastName is Peacock

# %% [markdown]
# ## Answer 2-c
# ### What product was ordered the most by customers in Germany?

# %% [markdown]
# `SELECT p.ProductName FROM Orders o, OrderDetails d, Customers c, Products p where o.OrderID=d.OrderID and o.CustomerID=c.CustomerID and p.ProductID=d.ProductID and c.Country='Germany'group by d.ProductID order by sum(Quantity) desc limit 1;`
#
# Boston Crab Meat was most ordered by customers in Germany.
